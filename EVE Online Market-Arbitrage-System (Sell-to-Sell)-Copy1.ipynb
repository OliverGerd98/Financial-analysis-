# %%
# ============================================================
# EVE Tycoon – Market Debug Notebook
# Skills | Blueprints | Weapons
# ============================================================

import requests
import pandas as pd
import time

BASE_URL = "https://evetycoon.com/api"

# ------------------------------------------------------------
# 1️⃣ Hilfsfunktionen
# ------------------------------------------------------------

def get_json(url):
    """GET-Request mit Wiederholversuchen & Textausgabe"""
    for attempt in range(3):
        try:
            r = requests.get(url, timeout=20)
            if r.status_code == 200:
                return r.json()
            else:
                print(f"⚠️  Fehler {r.status_code} bei {url}")
        except Exception as e:
            print(f"⚠️  Netzwerkfehler bei {url}: {e}")
        print("   ↪️  Versuch erneut in 2 Sekunden...")
        time.sleep(2)
    print(f"❌ Keine Antwort von {url}")
    return None


def get_market_groups():
    """Alle Market-Gruppen abrufen"""
    print("🔹 Lade Market-Groups...")
    data = get_json(f"{BASE_URL}/v1/market/groups")
    if not data:
        raise RuntimeError("❌ Keine Market-Groups erhalten.")
    print(f"✅ {len(data)} Market-Groups geladen.\n")
    return data


def get_items_in_group(group_id, group_name):
    """Alle Items innerhalb einer Market-Gruppe abrufen"""
    print(f"   → Lade Items aus Gruppe: {group_name}")
    data = get_json(f"{BASE_URL}/v1/market/groups/{group_id}/types")
    if data:
        print(f"     ✅ {len(data)} Items gefunden.")
    else:
        print("     ⚠️  Keine Items gefunden.")
    return data or []


def get_orders_for_item(type_id, type_name):
    """Alle Orders für ein Item abrufen"""
    url = f"{BASE_URL}/v1/market/orders/{type_id}"
    data = get_json(url)
    if not data or "orders" not in data:
        print(f"     ⚠️  Keine Orders für {type_name}")
        return None
    return data


# ------------------------------------------------------------
# 2️⃣ Relevante Gruppen finden
# ------------------------------------------------------------

groups = get_market_groups()

target_groups = [
    g for g in groups
    if any(keyword in g["marketGroupName"].lower() for keyword in ["skill", "blueprint", "weapon"])
]

print(f"🎯 Gefundene relevante Gruppen: {len(target_groups)}")
for g in target_groups:
    print(f"   - {g['marketGroupName']}")
print("")

# ------------------------------------------------------------
# 3️⃣ Alle Items aus diesen Gruppen laden
# ------------------------------------------------------------

all_items = []
for g in target_groups:
    items = get_items_in_group(g["marketGroupID"], g["marketGroupName"])
    all_items.extend(items)
    time.sleep(0.2)

print(f"\n📦 Gesamtanzahl Items: {len(all_items)}\n")

# ------------------------------------------------------------
# 4️⃣ Daten sammeln: günstigste & teuerste Verkaufsorders
# ------------------------------------------------------------

rows = []
print("🚀 Beginne mit Abruf der Orders...\n")

for i, item in enumerate(all_items, 1):
    type_id = item["typeID"]
    type_name = item["typeName"]
    print(f"[{i}/{len(all_items)}] → Lade Orders für {type_name}")

    orders_data = get_orders_for_item(type_id, type_name)
    if not orders_data:
        continue

    # Nur Sell Orders mit Bestand
    sell_orders = [o for o in orders_data["orders"] if not o["isBuyOrder"] and o["volumeRemain"] > 0]
    if len(sell_orders) == 0:
        print("   ⚠️  Keine aktiven Sell Orders gefunden.")
        continue

    sell_orders_sorted = sorted(sell_orders, key=lambda x: x["price"])
    cheapest5 = sell_orders_sorted[:5]
    expensive5 = sell_orders_sorted[-5:]

    stations = orders_data.get("stationNames", {})
    systems = orders_data.get("systems", {})
    structures = orders_data.get("structureNames", {})

    for tag, order_list in [("Cheapest", cheapest5), ("MostExpensive", expensive5)]:
        for o in order_list:
            loc_id = str(o["locationId"])
            sys_id = str(o["systemId"])

            region_id = o["regionId"]
            system_name = systems.get(sys_id, {}).get("solarSystemName", sys_id)
            region_name = systems.get(sys_id, {}).get("regionName", region_id)
            station_name = stations.get(loc_id, "")
            structure_name = structures.get(loc_id, "")

            rows.append({
                "typeID": type_id,
                "typeName": type_name,
                "orderType": tag,
                "price": o["price"],
                "volumeRemain": o["volumeRemain"],
                "regionName": region_name,
                "systemName": system_name,
                "stationName": station_name,
                "structureName": structure_name
            })

    time.sleep(0.2)

# ------------------------------------------------------------
# 5️⃣ Debug-Auswertung
# ------------------------------------------------------------

print("\n=== Debug Report ===")
print(f"Gefundene Orders insgesamt: {len(rows)}")

if len(rows) == 0:
    print("⚠️  Es wurden keine Orders gefunden. Teste manuell mit PLEX.")
    test_url = f"{BASE_URL}/v1/market/orders/44992"
    test_data = get_json(test_url)
    print(f"   Anzahl Orders für PLEX: {len(test_data.get('orders', [])) if test_data else 0}")
else:
    print("✅ Daten wurden gesammelt – erstelle DataFrame...")

# ------------------------------------------------------------
# 6️⃣ Anzeige im Notebook
# ------------------------------------------------------------

if len(rows) > 0:
    df = pd.DataFrame(rows)
    df_sorted = df.sort_values(by=["typeName", "orderType", "price"]).reset_index(drop=True)

    pd.set_option("display.max_rows", 30)
    pd.set_option("display.max_columns", None)
    pd.set_option("display.width", 200)

    print(f"\n✅ Fertig! {len(df_sorted)} Orders geladen.")
    print("\n📈 Beispielauszug:\n")
    display(df_sorted.head(20))
else:
    print("❌ Keine Daten zum Anzeigen.")
# Out:
# 🔹 Lade Market-Groups...
# ✅ 2038 Market-Groups geladen.
#
# 🎯 Gefundene relevante Gruppen: 51
#    - Blueprints & Reactions
#    - Weapon Upgrades
#    - Skills
#    - Weapon Upgrades
#    - Weapon Batteries
#    - Skill Hardwiring
#    - Weapon Disruptors
#    - Superweapons
#    - Superweapons
#    - Energy Weapon Rigs
#    - Hybrid Weapon Rigs
#    - Projectile Weapon Rigs
#    - Energy Weapon Rigs
#    - Hybrid Weapon Rigs
#    - Projectile Weapon Rigs
#    - Small Energy Weapon Rigs
#    - Medium Energy Weapon Rigs
#    - Large Energy Weapon Rigs
#    - Small Hybrid Weapon Rigs
#    - Medium Hybrid Weapon Rigs
#    - Large Hybrid Weapon Rigs
#    - Small Projectile Weapon Rigs
#    - Medium Projectile Weapon Rigs
#    - Large Projectile Weapon Rigs
#    - Small Energy Weapon Rigs
#    - Medium Energy Weapon Rigs
#    - Large Energy Weapon Rigs
#    - Small Hybrid Weapon Rigs
#    - Medium Hybrid Weapon Rigs
#    - Large Hybrid Weapon Rigs
#    - Small Projectile Weapon Rigs
#    - Medium Projectile Weapon Rigs
#    - Large Projectile Weapon Rigs
#    - Weapon Batteries
#    - Weapon Disruptors
#    - Special Edition Blueprints
#    - Capital Energy Weapon Rigs
#    - Capital Hybrid Weapon Rigs
#    - Capital Projectile Weapon Rigs
#    - Capital Projectile Weapon Rigs
#    - Capital Hybrid Weapon Rigs
#    - Capital Energy Weapon Rigs
#    - Structure Weapons
#    - Weapon Disruptors
#    - Weapon Upgrades
#    - Structure Weapons
#    - Weapon Disruptors
#    - Weapon Upgrades
#    - Skill Trading
#    - Weapon Upgrade Mutaplasmids
#    - Compressor Blueprints
#
#    → Lade Items aus Gruppe: Blueprints & Reactions
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Weapon Upgrades
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Skills
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Weapon Upgrades
#      ✅ 20 Items gefunden.
#    → Lade Items aus Gruppe: Weapon Batteries
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Skill Hardwiring
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Weapon Disruptors
#      ✅ 12 Items gefunden.
#    → Lade Items aus Gruppe: Superweapons
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Superweapons
#      ✅ 23 Items gefunden.
#    → Lade Items aus Gruppe: Energy Weapon Rigs
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Hybrid Weapon Rigs
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Projectile Weapon Rigs
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Energy Weapon Rigs
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Hybrid Weapon Rigs
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Projectile Weapon Rigs
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Small Energy Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Medium Energy Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Large Energy Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Small Hybrid Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Medium Hybrid Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Large Hybrid Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Small Projectile Weapon Rigs
#      ✅ 10 Items gefunden.
#    → Lade Items aus Gruppe: Medium Projectile Weapon Rigs
#      ✅ 10 Items gefunden.
#    → Lade Items aus Gruppe: Large Projectile Weapon Rigs
#      ✅ 10 Items gefunden.
#    → Lade Items aus Gruppe: Small Energy Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Medium Energy Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Large Energy Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Small Hybrid Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Medium Hybrid Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Large Hybrid Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Small Projectile Weapon Rigs
#      ✅ 5 Items gefunden.
#    → Lade Items aus Gruppe: Medium Projectile Weapon Rigs
#      ✅ 5 Items gefunden.
#    → Lade Items aus Gruppe: Large Projectile Weapon Rigs
#      ✅ 5 Items gefunden.
#    → Lade Items aus Gruppe: Weapon Batteries
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Weapon Disruptors
#      ✅ 2 Items gefunden.
#    → Lade Items aus Gruppe: Special Edition Blueprints
#      ✅ 1 Items gefunden.
#    → Lade Items aus Gruppe: Capital Energy Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Capital Hybrid Weapon Rigs
#      ✅ 7 Items gefunden.
#    → Lade Items aus Gruppe: Capital Projectile Weapon Rigs
#      ✅ 5 Items gefunden.
#    → Lade Items aus Gruppe: Capital Projectile Weapon Rigs
#      ✅ 10 Items gefunden.
#    → Lade Items aus Gruppe: Capital Hybrid Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Capital Energy Weapon Rigs
#      ✅ 14 Items gefunden.
#    → Lade Items aus Gruppe: Structure Weapons
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Weapon Disruptors
#      ✅ 1 Items gefunden.
#    → Lade Items aus Gruppe: Weapon Upgrades
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Structure Weapons
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Weapon Disruptors
#      ✅ 2 Items gefunden.
#    → Lade Items aus Gruppe: Weapon Upgrades
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Skill Trading
#      ✅ 4 Items gefunden.
#    → Lade Items aus Gruppe: Weapon Upgrade Mutaplasmids
#      ⚠️  Keine Items gefunden.
#    → Lade Items aus Gruppe: Compressor Blueprints
#      ✅ 12 Items gefunden.
#
# 📦 Gesamtanzahl Items: 305
#
# 🚀 Beginne mit Abruf der Orders...
#
# [1/305] → Lade Orders für Gyrostabilizer I Blueprint
# [2/305] → Lade Orders für Magnetic Field Stabilizer I Blueprint
# [3/305] → Lade Orders für Heat Sink I Blueprint
# [4/305] → Lade Orders für Tracking Enhancer I Blueprint
# [5/305] → Lade Orders für Remote Tracking Computer I Blueprint
# [6/305] → Lade Orders für Tracking Computer I Blueprint
# [7/305] → Lade Orders für Ballistic Control System I Blueprint
# [8/305] → Lade Orders für Siege Module I Blueprint
# [9/305] → Lade Orders für Triage Module I Blueprint
# [10/305] → Lade Orders für Capital Industrial Core I Blueprint
# [11/305] → Lade Orders für Bastion Module I Blueprint
# [12/305] → Lade Orders für Missile Guidance Enhancer I Blueprint
# [13/305] → Lade Orders für Missile Guidance Computer I Blueprint
# [14/305] → Lade Orders für Entropic Radiation Sink I Blueprint
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [15/305] → Lade Orders für ML-EKP 'Polybolos' Ballistic Control System Blueprint
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [16/305] → Lade Orders für Veles Entropic Radiation Sink Blueprint
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [17/305] → Lade Orders für Large Industrial Core I Blueprint
# [18/305] → Lade Orders für Medium Industrial Core I Blueprint
# [19/305] → Lade Orders für Consortium Vorton Tuning System Blueprint
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [20/305] → Lade Orders für Kasiha's Modified Vorton Tuning System Blueprint
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [21/305] → Lade Orders für Tracking Disruptor I
# [22/305] → Lade Orders für Tracking Disruptor II
# [23/305] → Lade Orders für Baker Nunn Enduring Tracking Disruptor I
# [24/305] → Lade Orders für Balmer Series Compact Tracking Disruptor I
# [25/305] → Lade Orders für C-IR Compact Guidance Disruptor
# [26/305] → Lade Orders für DDO Scoped Tracking Disruptor I
# [27/305] → Lade Orders für 'Distributor' Guidance Disruptor
# [28/305] → Lade Orders für 'Investor' Tracking Disruptor I
# [29/305] → Lade Orders für Guidance Disruptor I
# [30/305] → Lade Orders für Highstroke Scoped Guidance Disruptor
# [31/305] → Lade Orders für A-211 Enduring Guidance Disruptor
# [32/305] → Lade Orders für Guidance Disruptor II
# [33/305] → Lade Orders für 'Gjallarhorn' Explosive Doomsday Blueprint
# [34/305] → Lade Orders für 'Judgment' Electromagnetic Doomsday Blueprint
# [35/305] → Lade Orders für 'Oblivion' Kinetic Doomsday Blueprint
# [36/305] → Lade Orders für 'Aurora Ominae' Thermal Doomsday Blueprint
# [37/305] → Lade Orders für Gravitational Transportation Field Oscillator Blueprint
# [38/305] → Lade Orders für 'Holy Destiny' Electromagnetic Lance Blueprint
# [39/305] → Lade Orders für 'Iron Pike' Kinetic Lance Blueprint
# [40/305] → Lade Orders für 'Phalarica' Thermal Lance Blueprint
# [41/305] → Lade Orders für 'Geiravor' Explosive Lance Blueprint
# [42/305] → Lade Orders für 'Cold Wind' Kinetic Reaper Blueprint
# [43/305] → Lade Orders für 'Guillotine' Thermal Reaper Blueprint
# [44/305] → Lade Orders für 'Jormungandr' Explosive Reaper Blueprint
# [45/305] → Lade Orders für 'Divine Harvest' Electromagnetic Reaper Blueprint
# [46/305] → Lade Orders für Bosonic Field Generator Blueprint
# [47/305] → Lade Orders für Pulse Activated Nexus Invulnerability Core Blueprint
# [48/305] → Lade Orders für Amarr Phenomena Generator Blueprint
# [49/305] → Lade Orders für Caldari Phenomena Generator Blueprint
# [50/305] → Lade Orders für Gallente Phenomena Generator Blueprint
# [51/305] → Lade Orders für Minmatar Phenomena Generator Blueprint
# [52/305] → Lade Orders für 'Atgeir' Explosive Disruptive Lance Blueprint
# [53/305] → Lade Orders für 'Azmaru' Electromagnetic Disruptive Lance Blueprint
# [54/305] → Lade Orders für 'Steel Yari' Kinetic Disruptive Lance Blueprint
# [55/305] → Lade Orders für 'Sarissa' Thermal Disruptive Lance Blueprint
# [56/305] → Lade Orders für Small Algid Energy Administrations Unit I
# [57/305] → Lade Orders für Small Algid Energy Administrations Unit II
# [58/305] → Lade Orders für Small Energy Ambit Extension I
# [59/305] → Lade Orders für Small Energy Ambit Extension II
# [60/305] → Lade Orders für Small Energy Burst Aerator I
# [61/305] → Lade Orders für Small Energy Burst Aerator II
# [62/305] → Lade Orders für Small Energy Collision Accelerator I
# [63/305] → Lade Orders für Small Energy Collision Accelerator II
# [64/305] → Lade Orders für Small Energy Discharge Elutriation I
# [65/305] → Lade Orders für Small Energy Discharge Elutriation II
# [66/305] → Lade Orders für Small Energy Locus Coordinator I
# [67/305] → Lade Orders für Small Energy Locus Coordinator II
# [68/305] → Lade Orders für Small Energy Metastasis Adjuster I
# [69/305] → Lade Orders für Small Energy Metastasis Adjuster II
# [70/305] → Lade Orders für Medium Algid Energy Administrations Unit I
# [71/305] → Lade Orders für Medium Algid Energy Administrations Unit II
# [72/305] → Lade Orders für Medium Energy Ambit Extension I
# [73/305] → Lade Orders für Medium Energy Ambit Extension II
# [74/305] → Lade Orders für Medium Energy Burst Aerator I
# [75/305] → Lade Orders für Medium Energy Burst Aerator II
# [76/305] → Lade Orders für Medium Energy Collision Accelerator I
# [77/305] → Lade Orders für Medium Energy Collision Accelerator II
# [78/305] → Lade Orders für Medium Energy Discharge Elutriation I
# [79/305] → Lade Orders für Medium Energy Discharge Elutriation II
# [80/305] → Lade Orders für Medium Energy Locus Coordinator I
# [81/305] → Lade Orders für Medium Energy Locus Coordinator II
# [82/305] → Lade Orders für Medium Energy Metastasis Adjuster I
# [83/305] → Lade Orders für Medium Energy Metastasis Adjuster II
# [84/305] → Lade Orders für Large Energy Discharge Elutriation I
# [85/305] → Lade Orders für Large Energy Ambit Extension I
# [86/305] → Lade Orders für Large Energy Locus Coordinator I
# [87/305] → Lade Orders für Large Energy Metastasis Adjuster I
# [88/305] → Lade Orders für Large Algid Energy Administrations Unit I
# [89/305] → Lade Orders für Large Energy Burst Aerator I
# [90/305] → Lade Orders für Large Energy Collision Accelerator I
# [91/305] → Lade Orders für Large Energy Discharge Elutriation II
# [92/305] → Lade Orders für Large Energy Burst Aerator II
# [93/305] → Lade Orders für Large Energy Collision Accelerator II
# [94/305] → Lade Orders für Large Algid Energy Administrations Unit II
# [95/305] → Lade Orders für Large Energy Ambit Extension II
# [96/305] → Lade Orders für Large Energy Locus Coordinator II
# [97/305] → Lade Orders für Large Energy Metastasis Adjuster II
# [98/305] → Lade Orders für Small Algid Hybrid Administrations Unit I
# [99/305] → Lade Orders für Small Algid Hybrid Administrations Unit II
# [100/305] → Lade Orders für Small Hybrid Ambit Extension I
# [101/305] → Lade Orders für Small Hybrid Ambit Extension II
# [102/305] → Lade Orders für Small Hybrid Burst Aerator I
# [103/305] → Lade Orders für Small Hybrid Burst Aerator II
# [104/305] → Lade Orders für Small Hybrid Collision Accelerator I
# [105/305] → Lade Orders für Small Hybrid Collision Accelerator II
# [106/305] → Lade Orders für Small Hybrid Discharge Elutriation I
# [107/305] → Lade Orders für Small Hybrid Discharge Elutriation II
# [108/305] → Lade Orders für Small Hybrid Locus Coordinator I
# [109/305] → Lade Orders für Small Hybrid Locus Coordinator II
# [110/305] → Lade Orders für Small Hybrid Metastasis Adjuster I
# [111/305] → Lade Orders für Small Hybrid Metastasis Adjuster II
# [112/305] → Lade Orders für Medium Algid Hybrid Administrations Unit I
# [113/305] → Lade Orders für Medium Algid Hybrid Administrations Unit II
# [114/305] → Lade Orders für Medium Hybrid Ambit Extension I
# [115/305] → Lade Orders für Medium Hybrid Ambit Extension II
# [116/305] → Lade Orders für Medium Hybrid Burst Aerator I
# [117/305] → Lade Orders für Medium Hybrid Burst Aerator II
# [118/305] → Lade Orders für Medium Hybrid Collision Accelerator I
# [119/305] → Lade Orders für Medium Hybrid Collision Accelerator II
# [120/305] → Lade Orders für Medium Hybrid Discharge Elutriation I
# [121/305] → Lade Orders für Medium Hybrid Discharge Elutriation II
# [122/305] → Lade Orders für Medium Hybrid Locus Coordinator I
# [123/305] → Lade Orders für Medium Hybrid Locus Coordinator II
# [124/305] → Lade Orders für Medium Hybrid Metastasis Adjuster I
# [125/305] → Lade Orders für Medium Hybrid Metastasis Adjuster II
# [126/305] → Lade Orders für Large Hybrid Discharge Elutriation I
# [127/305] → Lade Orders für Large Hybrid Ambit Extension I
# [128/305] → Lade Orders für Large Hybrid Locus Coordinator I
# [129/305] → Lade Orders für Large Hybrid Metastasis Adjuster I
# [130/305] → Lade Orders für Large Algid Hybrid Administrations Unit I
# [131/305] → Lade Orders für Large Hybrid Burst Aerator I
# [132/305] → Lade Orders für Large Hybrid Collision Accelerator I
# [133/305] → Lade Orders für Large Hybrid Discharge Elutriation II
# [134/305] → Lade Orders für Large Hybrid Burst Aerator II
# [135/305] → Lade Orders für Large Hybrid Collision Accelerator II
# [136/305] → Lade Orders für Large Algid Hybrid Administrations Unit II
# [137/305] → Lade Orders für Large Hybrid Ambit Extension II
# [138/305] → Lade Orders für Large Hybrid Locus Coordinator II
# [139/305] → Lade Orders für Large Hybrid Metastasis Adjuster II
# [140/305] → Lade Orders für Small Projectile Ambit Extension I
# [141/305] → Lade Orders für Small Projectile Ambit Extension II
# [142/305] → Lade Orders für Small Projectile Burst Aerator I
# [143/305] → Lade Orders für Small Projectile Burst Aerator II
# [144/305] → Lade Orders für Small Projectile Collision Accelerator I
# [145/305] → Lade Orders für Small Projectile Collision Accelerator II
# [146/305] → Lade Orders für Small Projectile Locus Coordinator I
# [147/305] → Lade Orders für Small Projectile Locus Coordinator II
# [148/305] → Lade Orders für Small Projectile Metastasis Adjuster I
# [149/305] → Lade Orders für Small Projectile Metastasis Adjuster II
# [150/305] → Lade Orders für Medium Projectile Ambit Extension I
# [151/305] → Lade Orders für Medium Projectile Ambit Extension II
# [152/305] → Lade Orders für Medium Projectile Burst Aerator I
# [153/305] → Lade Orders für Medium Projectile Burst Aerator II
# [154/305] → Lade Orders für Medium Projectile Collision Accelerator I
# [155/305] → Lade Orders für Medium Projectile Collision Accelerator II
# [156/305] → Lade Orders für Medium Projectile Locus Coordinator I
# [157/305] → Lade Orders für Medium Projectile Locus Coordinator II
# [158/305] → Lade Orders für Medium Projectile Metastasis Adjuster I
# [159/305] → Lade Orders für Medium Projectile Metastasis Adjuster II
# [160/305] → Lade Orders für Large Projectile Ambit Extension I
# [161/305] → Lade Orders für Large Projectile Locus Coordinator I
# [162/305] → Lade Orders für Large Projectile Metastasis Adjuster I
# [163/305] → Lade Orders für Large Projectile Burst Aerator I
# [164/305] → Lade Orders für Large Projectile Collision Accelerator I
# [165/305] → Lade Orders für Large Projectile Collision Accelerator II
# [166/305] → Lade Orders für Large Projectile Ambit Extension II
# [167/305] → Lade Orders für Large Projectile Burst Aerator II
# [168/305] → Lade Orders für Large Projectile Locus Coordinator II
# [169/305] → Lade Orders für Large Projectile Metastasis Adjuster II
# [170/305] → Lade Orders für Small Algid Energy Administrations Unit I Blueprint
# [171/305] → Lade Orders für Small Energy Ambit Extension I Blueprint
# [172/305] → Lade Orders für Small Energy Burst Aerator I Blueprint
# [173/305] → Lade Orders für Small Energy Collision Accelerator I Blueprint
# [174/305] → Lade Orders für Small Energy Discharge Elutriation I Blueprint
# [175/305] → Lade Orders für Small Energy Locus Coordinator I Blueprint
# [176/305] → Lade Orders für Small Energy Metastasis Adjuster I Blueprint
# [177/305] → Lade Orders für Medium Algid Energy Administrations Unit I Blueprint
# [178/305] → Lade Orders für Medium Energy Ambit Extension I Blueprint
# [179/305] → Lade Orders für Medium Energy Burst Aerator I Blueprint
# [180/305] → Lade Orders für Medium Energy Collision Accelerator I Blueprint
# [181/305] → Lade Orders für Medium Energy Discharge Elutriation I Blueprint
# [182/305] → Lade Orders für Medium Energy Locus Coordinator I Blueprint
# [183/305] → Lade Orders für Medium Energy Metastasis Adjuster I Blueprint
# [184/305] → Lade Orders für Large Energy Discharge Elutriation I Blueprint
# [185/305] → Lade Orders für Large Energy Ambit Extension I Blueprint
# [186/305] → Lade Orders für Large Energy Locus Coordinator I Blueprint
# [187/305] → Lade Orders für Large Energy Metastasis Adjuster I Blueprint
# [188/305] → Lade Orders für Large Algid Energy Administrations Unit I Blueprint
# [189/305] → Lade Orders für Large Energy Burst Aerator I Blueprint
# [190/305] → Lade Orders für Large Energy Collision Accelerator I Blueprint
# [191/305] → Lade Orders für Small Algid Hybrid Administrations Unit I Blueprint
# [192/305] → Lade Orders für Small Hybrid Ambit Extension I Blueprint
# [193/305] → Lade Orders für Small Hybrid Burst Aerator I Blueprint
# [194/305] → Lade Orders für Small Hybrid Collision Accelerator I Blueprint
# [195/305] → Lade Orders für Small Hybrid Discharge Elutriation I Blueprint
# [196/305] → Lade Orders für Small Hybrid Locus Coordinator I Blueprint
# [197/305] → Lade Orders für Small Hybrid Metastasis Adjuster I Blueprint
# [198/305] → Lade Orders für Medium Algid Hybrid Administrations Unit I Blueprint
# [199/305] → Lade Orders für Medium Hybrid Ambit Extension I Blueprint
# [200/305] → Lade Orders für Medium Hybrid Burst Aerator I Blueprint
# [201/305] → Lade Orders für Medium Hybrid Collision Accelerator I Blueprint
# [202/305] → Lade Orders für Medium Hybrid Discharge Elutriation I Blueprint
# [203/305] → Lade Orders für Medium Hybrid Locus Coordinator I Blueprint
# [204/305] → Lade Orders für Medium Hybrid Metastasis Adjuster I Blueprint
# [205/305] → Lade Orders für Large Hybrid Discharge Elutriation I Blueprint
# [206/305] → Lade Orders für Large Hybrid Ambit Extension I Blueprint
# [207/305] → Lade Orders für Large Hybrid Locus Coordinator I Blueprint
# [208/305] → Lade Orders für Large Hybrid Metastasis Adjuster I Blueprint
# [209/305] → Lade Orders für Large Algid Hybrid Administrations Unit I Blueprint
# [210/305] → Lade Orders für Large Hybrid Burst Aerator I Blueprint
# [211/305] → Lade Orders für Large Hybrid Collision Accelerator I Blueprint
# [212/305] → Lade Orders für Small Projectile Ambit Extension I Blueprint
# [213/305] → Lade Orders für Small Projectile Burst Aerator I Blueprint
# [214/305] → Lade Orders für Small Projectile Collision Accelerator I Blueprint
# [215/305] → Lade Orders für Small Projectile Locus Coordinator I Blueprint
# [216/305] → Lade Orders für Small Projectile Metastasis Adjuster I Blueprint
# [217/305] → Lade Orders für Medium Projectile Ambit Extension I Blueprint
# [218/305] → Lade Orders für Medium Projectile Burst Aerator I Blueprint
# [219/305] → Lade Orders für Medium Projectile Collision Accelerator I Blueprint
# [220/305] → Lade Orders für Medium Projectile Locus Coordinator I Blueprint
# [221/305] → Lade Orders für Medium Projectile Metastasis Adjuster I Blueprint
# [222/305] → Lade Orders für Large Projectile Ambit Extension I Blueprint
# [223/305] → Lade Orders für Large Projectile Locus Coordinator I Blueprint
# [224/305] → Lade Orders für Large Projectile Metastasis Adjuster I Blueprint
# [225/305] → Lade Orders für Large Projectile Burst Aerator I Blueprint
# [226/305] → Lade Orders für Large Projectile Collision Accelerator I Blueprint
# [227/305] → Lade Orders für Tracking Disruptor I Blueprint
# [228/305] → Lade Orders für Guidance Disruptor I Blueprint
# [229/305] → Lade Orders für Deactivated Station Key Pass Blueprint
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [230/305] → Lade Orders für Capital Algid Energy Administrations Unit I Blueprint
# [231/305] → Lade Orders für Capital Energy Ambit Extension I Blueprint
# [232/305] → Lade Orders für Capital Energy Burst Aerator I Blueprint
# [233/305] → Lade Orders für Capital Energy Collision Accelerator I Blueprint
# [234/305] → Lade Orders für Capital Energy Discharge Elutriation I Blueprint
# [235/305] → Lade Orders für Capital Energy Locus Coordinator I Blueprint
# [236/305] → Lade Orders für Capital Energy Metastasis Adjuster I Blueprint
# [237/305] → Lade Orders für Capital Algid Hybrid Administrations Unit I Blueprint
# [238/305] → Lade Orders für Capital Hybrid Ambit Extension I Blueprint
# [239/305] → Lade Orders für Capital Hybrid Burst Aerator I Blueprint
# [240/305] → Lade Orders für Capital Hybrid Collision Accelerator I Blueprint
# [241/305] → Lade Orders für Capital Hybrid Discharge Elutriation I Blueprint
# [242/305] → Lade Orders für Capital Hybrid Locus Coordinator I Blueprint
# [243/305] → Lade Orders für Capital Hybrid Metastasis Adjuster I Blueprint
# [244/305] → Lade Orders für Capital Projectile Ambit Extension I Blueprint
# [245/305] → Lade Orders für Capital Projectile Burst Aerator I Blueprint
# [246/305] → Lade Orders für Capital Projectile Collision Accelerator I Blueprint
# [247/305] → Lade Orders für Capital Projectile Locus Coordinator I Blueprint
# [248/305] → Lade Orders für Capital Projectile Metastasis Adjuster I Blueprint
# [249/305] → Lade Orders für Capital Projectile Ambit Extension I
# [250/305] → Lade Orders für Capital Projectile Ambit Extension II
# [251/305] → Lade Orders für Capital Projectile Burst Aerator I
# [252/305] → Lade Orders für Capital Projectile Burst Aerator II
# [253/305] → Lade Orders für Capital Projectile Collision Accelerator I
# [254/305] → Lade Orders für Capital Projectile Collision Accelerator II
# [255/305] → Lade Orders für Capital Projectile Locus Coordinator I
# [256/305] → Lade Orders für Capital Projectile Locus Coordinator II
# [257/305] → Lade Orders für Capital Projectile Metastasis Adjuster I
# [258/305] → Lade Orders für Capital Projectile Metastasis Adjuster II
# [259/305] → Lade Orders für Capital Algid Hybrid Administrations Unit I
# [260/305] → Lade Orders für Capital Algid Hybrid Administrations Unit II
# [261/305] → Lade Orders für Capital Hybrid Ambit Extension I
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [262/305] → Lade Orders für Capital Hybrid Ambit Extension II
# [263/305] → Lade Orders für Capital Hybrid Burst Aerator I
# [264/305] → Lade Orders für Capital Hybrid Burst Aerator II
# [265/305] → Lade Orders für Capital Hybrid Collision Accelerator I
# [266/305] → Lade Orders für Capital Hybrid Collision Accelerator II
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [267/305] → Lade Orders für Capital Hybrid Discharge Elutriation I
# [268/305] → Lade Orders für Capital Hybrid Discharge Elutriation II
# [269/305] → Lade Orders für Capital Hybrid Locus Coordinator I
# [270/305] → Lade Orders für Capital Hybrid Locus Coordinator II
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [271/305] → Lade Orders für Capital Hybrid Metastasis Adjuster I
# [272/305] → Lade Orders für Capital Hybrid Metastasis Adjuster II
# [273/305] → Lade Orders für Capital Algid Energy Administrations Unit I
# [274/305] → Lade Orders für Capital Algid Energy Administrations Unit II
# [275/305] → Lade Orders für Capital Energy Ambit Extension I
# [276/305] → Lade Orders für Capital Energy Ambit Extension II
# [277/305] → Lade Orders für Capital Energy Burst Aerator I
# [278/305] → Lade Orders für Capital Energy Burst Aerator II
# [279/305] → Lade Orders für Capital Energy Collision Accelerator I
# [280/305] → Lade Orders für Capital Energy Collision Accelerator II
# [281/305] → Lade Orders für Capital Energy Discharge Elutriation I
#    ⚠️  Keine aktiven Sell Orders gefunden.
# [282/305] → Lade Orders für Capital Energy Discharge Elutriation II
# [283/305] → Lade Orders für Capital Energy Locus Coordinator I
# [284/305] → Lade Orders für Capital Energy Locus Coordinator II
# [285/305] → Lade Orders für Capital Energy Metastasis Adjuster I
# [286/305] → Lade Orders für Capital Energy Metastasis Adjuster II
# [287/305] → Lade Orders für Standup Weapon Disruptor I Blueprint
# [288/305] → Lade Orders für Standup Weapon Disruptor I
# [289/305] → Lade Orders für Standup Weapon Disruptor II
# [290/305] → Lade Orders für Skill Extractor
# [291/305] → Lade Orders für Large Skill Injector
# [292/305] → Lade Orders für Small Skill Injector
# [293/305] → Lade Orders für Daily Alpha Injector
# [294/305] → Lade Orders für Medium Asteroid Ore Compressor I Blueprint
# [295/305] → Lade Orders für Large Asteroid Ore Compressor I Blueprint
# [296/305] → Lade Orders für Capital Asteroid Ore Compressor I Blueprint
# [297/305] → Lade Orders für Large Ice Compressor I Blueprint
# [298/305] → Lade Orders für Capital Ice Compressor I Blueprint
# [299/305] → Lade Orders für Medium Gas Compressor I Blueprint
# [300/305] → Lade Orders für Large Gas Compressor I Blueprint
# [301/305] → Lade Orders für Capital Gas Compressor I Blueprint
# [302/305] → Lade Orders für Large Mercoxit Compressor I Blueprint
# [303/305] → Lade Orders für Capital Mercoxit Compressor I Blueprint
# [304/305] → Lade Orders für Large Moon Ore Compressor I Blueprint
# [305/305] → Lade Orders für Capital Moon Ore Compressor I Blueprint
#
# === Debug Report ===
# Gefundene Orders insgesamt: 2842
# ✅ Daten wurden gesammelt – erstelle DataFrame...
#
# ✅ Fertig! 2842 Orders geladen.
#
# 📈 Beispielauszug:
#     typeID                                       typeName      orderType        price  volumeRemain  regionName      systemName                                        stationName structureName
# 0    77402  'Atgeir' Explosive Disruptive Lance Blueprint       Cheapest  500000000.0            16    10000028          Hrober      Hrober VI - Republic Fleet Testing Facilities
# 1    77402  'Atgeir' Explosive Disruptive Lance Blueprint       Cheapest  500000000.0            16    10000028          Hrober  Hrober VII - Moon 5 - Republic Fleet Testing F...
# 2    77402  'Atgeir' Explosive Disruptive Lance Blueprint       Cheapest  500000000.0            16    10000028         Sakulda  Sakulda IX - Moon 2 - Republic Fleet Testing F...
# 3    77402  'Atgeir' Explosive Disruptive Lance Blueprint       Cheapest  500000000.0            16    10000028  Hedaleolfarber  Hedaleolfarber IX - Moon 23 - Republic Fleet T...
# 4    77402  'Atgeir' Explosive Disruptive Lance Blueprint       Cheapest  500000000.0            16    10000028            Half   Half X - Moon 10 - Republic Fleet Assembly Plant
# 5    77402  'Atgeir' Explosive Disruptive Lance Blueprint  MostExpensive  500000000.0            33    10000001        Uzistoon        Uzistoon VII - Moon 2 - Thukker Mix Factory
# 6    77402  'Atgeir' Explosive Disruptive Lance Blueprint  MostExpensive  500000000.0            33    10000001           Nakah             Nakah I - Moon 1 - Thukker Mix Factory
# 7    77402  'Atgeir' Explosive Disruptive Lance Blueprint  MostExpensive  697000000.0             1    10000032         Dodixie  Dodixie IX - Moon 20 - Federation Navy Assembl...
# 8    77402  'Atgeir' Explosive Disruptive Lance Blueprint  MostExpensive  699800000.0             1    10000043           Amarr         Amarr VIII (Oris) - Emperor Family Academy
# 9    77402  'Atgeir' Explosive Disruptive Lance Blueprint  MostExpensive  699900000.0             2    10000002            Jita     Jita IV - Moon 4 - Caldari Navy Assembly Plant
# 10   24555     'Aurora Ominae' Thermal Doomsday Blueprint       Cheapest  240950758.0            16    10000032        Vittenyn  Vittenyn VI - Moon 13 - Federation Navy Assemb...
# 11   24555     'Aurora Ominae' Thermal Doomsday Blueprint       Cheapest  240950758.0            16    10000048         Orvolle         Orvolle I - Federation Navy Assembly Plant
# 12   24555     'Aurora Ominae' Thermal Doomsday Blueprint       Cheapest  240950758.0            16    10000064       Algogille  Algogille XIII - Federation Navy Testing Facil...
# 13   24555     'Aurora Ominae' Thermal Doomsday Blueprint       Cheapest  240950758.0            16    10000064      Oursulaert  Oursulaert III - Federation Navy Testing Facil...
# 14   24555     'Aurora Ominae' Thermal Doomsday Blueprint       Cheapest  240950758.0            16    10000064      Oursulaert  Oursulaert IV - Federation Navy Testing Facili...
# 15   24555     'Aurora Ominae' Thermal Doomsday Blueprint  MostExpensive  240950758.0            16    10000032        Fricoure  Fricoure VIII - Moon 2 - Federation Navy Assem...
# 16   24555     'Aurora Ominae' Thermal Doomsday Blueprint  MostExpensive  240950758.0            16    10000032         Caretyn  Caretyn VII - Moon 13 - Federation Navy Assemb...
# 17   24555     'Aurora Ominae' Thermal Doomsday Blueprint  MostExpensive  240950758.0            16    10000032             Jel  Jel VIII - Moon 20 - Federation Navy Assembly ...
# 18   24555     'Aurora Ominae' Thermal Doomsday Blueprint  MostExpensive  321000000.0             1    10000002            Jita     Jita IV - Moon 4 - Caldari Navy Assembly Plant
# 19   24555     'Aurora Ominae' Thermal Doomsday Blueprint  MostExpensive  349000000.0             1    10000043           Amarr         Amarr VIII (Oris) - Emperor Family Academy

# %%
# ============================================================
# SELL→SELL Arbitrage über alle Sell-Orders je Station (bereinigt)
# - pro Station nur der niedrigste Verkaufspreis zählt
# - Verkauf = Station mit größtem Spread relativ zum globalen Einkauf
# ============================================================

import time
import pandas as pd
import datetime

# --- Sicherheits-Checks / Hilfen ---
if "all_items" not in locals():
    raise RuntimeError("⚠️ 'all_items' fehlt. Bitte zuerst die Zellen ausführen, die Market-Gruppen/Items laden.")

if "get_orders_for_item" not in locals():
    raise RuntimeError("⚠️ 'get_orders_for_item' fehlt. Bitte die API-Hilfsfunktionen-Zelle ausführen.")

def _label_row(system_name, region_name, station_name, structure_name):
    place = station_name if station_name else structure_name
    return f"{place} ({system_name}, {region_name})"

print("\n📦 Lade ALLE Sell-Orders für die ausgewählten Items (Station-basierte Aggregation)...")

all_sell_rows = []

for idx, item in enumerate(all_items, 1):
    type_id = item["typeID"]
    type_name = item["typeName"]
    print(f"[{idx}/{len(all_items)}] → Orders für: {type_name}")

    data = get_orders_for_item(type_id, type_name)
    if not data or "orders" not in data:
        continue

    stations = data.get("stationNames", {})
    structures = data.get("structureNames", {})
    systems = data.get("systems", {})

    # ALLE Sell-Orders (nicht nur Top 5/Top N)
    sells = [o for o in data["orders"] if not o.get("isBuyOrder", False) and o.get("volumeRemain", 0) > 0]
    if not sells:
        continue

    for o in sells:
        loc_id = str(o["locationId"])
        sys_id = str(o["systemId"])
        region_name = systems.get(sys_id, {}).get("regionName", o.get("regionId"))
        system_name = systems.get(sys_id, {}).get("solarSystemName", sys_id)
        station_name = stations.get(loc_id, "")
        structure_name = structures.get(loc_id, "")

        all_sell_rows.append({
            "typeID": type_id,
            "typeName": type_name,
            "locationId": loc_id,                 # 🔑 stabile Station/Struktur-ID
            "price": float(o["price"]),
            "volumeRemain": int(o.get("volumeRemain", 0)),
            "regionName": region_name,
            "systemName": system_name,
            "stationName": station_name,
            "structureName": structure_name,
            "Ort": _label_row(system_name, region_name, station_name, structure_name)
        })
    time.sleep(0.15)  # etwas sanfter fürs Rate-Limit

df_sells_all = pd.DataFrame(all_sell_rows)
if df_sells_all.empty:
    raise RuntimeError("❌ Keine Sell-Orders gefunden. Bitte vorherige Schritte/Filter prüfen.")

print(f"✅ Sell-Orders geladen: {len(df_sells_all):,}")

# ------------------------------------------------------------
# Gruppierung: pro Item & Station der MINDEST-PREIS (Station nur 1x)
# ------------------------------------------------------------
# Wir gruppieren über (typeName, locationId) und nehmen:
# - min_price: niedrigster Verkaufspreis an dieser Station
# - total_vol: Summe des noch verfügbaren Volumens an dieser Station (optional nützlich)
station_min_prices = (
    df_sells_all
    .groupby(["typeName", "locationId"], as_index=False)
    .agg(
        min_price=("price", "min"),
        total_vol=("volumeRemain", "sum"),
        Ort=("Ort", "first"),                     # repräsentatives Label
        regionName=("regionName", "first"),
        systemName=("systemName", "first"),
        stationName=("stationName", "first"),
        structureName=("structureName", "first"),
    )
)

# ------------------------------------------------------------
# Für jedes Item:
# - Einkauf: globaler Mindestpreis (über alle Stationen)
# - Verkauf: Station mit MAX(min_price) > buy_price (größter Spread), Station ≠ Einkaufs-Station
# ------------------------------------------------------------
records = []

for item_name, g in station_min_prices.groupby("typeName"):
    if len(g) < 2:
        continue

    # Einkauf
    buy_idx = g["min_price"].idxmin()
    buy_row = g.loc[buy_idx]
    buy_price = buy_row["min_price"]
    buy_loc_id = buy_row["locationId"]
    buy_loc_lbl = buy_row["Ort"]

    # Kandidaten für Verkauf: alle Stationen mit höherem Mindestpreis als Einkauf
    candidates = g[g["min_price"] > buy_price].copy()
    if candidates.empty:
        continue

    # Spread berechnen
    candidates["spread_abs"] = candidates["min_price"] - buy_price
    candidates["spread_pct"] = candidates["spread_abs"] / buy_price * 100

    # Sicherstellen, dass wir NICHT die gleiche Station wählen
    candidates = candidates[candidates["locationId"] != buy_loc_id]
    if candidates.empty:
        continue

    # Beste Verkaufsstation = größte spread_pct
    sell_row = candidates.sort_values("spread_pct", ascending=False).iloc[0]
    sell_price = sell_row["min_price"]
    sell_loc_lbl = sell_row["Ort"]

    records.append({
        "Item": item_name,
        "Einkaufspreis [ISK]": buy_price,
        "Einkaufs-Ort": buy_loc_lbl,
        "Verkaufspreis [ISK] (niedrigste Sell an Zielstation)": sell_price,
        "Verkaufs-Ort": sell_loc_lbl,
        "Spread [ISK]": sell_price - buy_price,
        "Spread [%]": (sell_price - buy_price) / buy_price * 100,
        "Volumen (Einkaufs-Station)": int(buy_row["total_vol"]),
        "Volumen (Verkaufs-Station)": int(sell_row["total_vol"]),
    })

spread_sell_to_sell = (
    pd.DataFrame(records)
    .sort_values("Spread [%]", ascending=False)
    .reset_index(drop=True)
)

print(f"✅ Tabelle erstellt: {len(spread_sell_to_sell):,} Items")

# Anzeige hübsch formatieren
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 320)

print("\n📈 Top 500 Sell→Sell-Spreads (Station-aggregiert, je Station min Preis):\n")
display(spread_sell_to_sell.head(500))

# ------------------------------------------------------------
# 💾 Export mit Datum
# ------------------------------------------------------------
today = datetime.date.today().strftime("%Y-%m-%d")
filename = f"Eve_Spread_500_{today}_sell_to_sell_clean.csv"
spread_sell_to_sell.head(500).to_csv(filename, index=False)
print(f"💾  Datei '{filename}' gespeichert.")
# Out:
# 📦 Lade ALLE Sell-Orders für die ausgewählten Items (Station-basierte Aggregation)...
# [1/305] → Orders für: Gyrostabilizer I Blueprint
# [2/305] → Orders für: Magnetic Field Stabilizer I Blueprint
# [3/305] → Orders für: Heat Sink I Blueprint
# [4/305] → Orders für: Tracking Enhancer I Blueprint
# [5/305] → Orders für: Remote Tracking Computer I Blueprint
# [6/305] → Orders für: Tracking Computer I Blueprint
# [7/305] → Orders für: Ballistic Control System I Blueprint
# [8/305] → Orders für: Siege Module I Blueprint
# [9/305] → Orders für: Triage Module I Blueprint
# [10/305] → Orders für: Capital Industrial Core I Blueprint
# [11/305] → Orders für: Bastion Module I Blueprint
# [12/305] → Orders für: Missile Guidance Enhancer I Blueprint
# [13/305] → Orders für: Missile Guidance Computer I Blueprint
# [14/305] → Orders für: Entropic Radiation Sink I Blueprint
# [15/305] → Orders für: ML-EKP 'Polybolos' Ballistic Control System Blueprint
# [16/305] → Orders für: Veles Entropic Radiation Sink Blueprint
# [17/305] → Orders für: Large Industrial Core I Blueprint
# [18/305] → Orders für: Medium Industrial Core I Blueprint
# [19/305] → Orders für: Consortium Vorton Tuning System Blueprint
# [20/305] → Orders für: Kasiha's Modified Vorton Tuning System Blueprint
# [21/305] → Orders für: Tracking Disruptor I
# [22/305] → Orders für: Tracking Disruptor II
# [23/305] → Orders für: Baker Nunn Enduring Tracking Disruptor I
# [24/305] → Orders für: Balmer Series Compact Tracking Disruptor I
# [25/305] → Orders für: C-IR Compact Guidance Disruptor
# [26/305] → Orders für: DDO Scoped Tracking Disruptor I
# [27/305] → Orders für: 'Distributor' Guidance Disruptor
# [28/305] → Orders für: 'Investor' Tracking Disruptor I
# [29/305] → Orders für: Guidance Disruptor I
# [30/305] → Orders für: Highstroke Scoped Guidance Disruptor
# [31/305] → Orders für: A-211 Enduring Guidance Disruptor
# [32/305] → Orders für: Guidance Disruptor II
# [33/305] → Orders für: 'Gjallarhorn' Explosive Doomsday Blueprint
# [34/305] → Orders für: 'Judgment' Electromagnetic Doomsday Blueprint
# [35/305] → Orders für: 'Oblivion' Kinetic Doomsday Blueprint
# [36/305] → Orders für: 'Aurora Ominae' Thermal Doomsday Blueprint
# [37/305] → Orders für: Gravitational Transportation Field Oscillator Blueprint
# [38/305] → Orders für: 'Holy Destiny' Electromagnetic Lance Blueprint
# [39/305] → Orders für: 'Iron Pike' Kinetic Lance Blueprint
# [40/305] → Orders für: 'Phalarica' Thermal Lance Blueprint
# [41/305] → Orders für: 'Geiravor' Explosive Lance Blueprint
# [42/305] → Orders für: 'Cold Wind' Kinetic Reaper Blueprint
# [43/305] → Orders für: 'Guillotine' Thermal Reaper Blueprint
# [44/305] → Orders für: 'Jormungandr' Explosive Reaper Blueprint
# [45/305] → Orders für: 'Divine Harvest' Electromagnetic Reaper Blueprint
# [46/305] → Orders für: Bosonic Field Generator Blueprint
# [47/305] → Orders für: Pulse Activated Nexus Invulnerability Core Blueprint
# [48/305] → Orders für: Amarr Phenomena Generator Blueprint
# [49/305] → Orders für: Caldari Phenomena Generator Blueprint
# [50/305] → Orders für: Gallente Phenomena Generator Blueprint
# [51/305] → Orders für: Minmatar Phenomena Generator Blueprint
# [52/305] → Orders für: 'Atgeir' Explosive Disruptive Lance Blueprint
# [53/305] → Orders für: 'Azmaru' Electromagnetic Disruptive Lance Blueprint
# [54/305] → Orders für: 'Steel Yari' Kinetic Disruptive Lance Blueprint
# [55/305] → Orders für: 'Sarissa' Thermal Disruptive Lance Blueprint
# [56/305] → Orders für: Small Algid Energy Administrations Unit I
# [57/305] → Orders für: Small Algid Energy Administrations Unit II
# [58/305] → Orders für: Small Energy Ambit Extension I
# [59/305] → Orders für: Small Energy Ambit Extension II
# [60/305] → Orders für: Small Energy Burst Aerator I
# [61/305] → Orders für: Small Energy Burst Aerator II
# [62/305] → Orders für: Small Energy Collision Accelerator I
# [63/305] → Orders für: Small Energy Collision Accelerator II
# [64/305] → Orders für: Small Energy Discharge Elutriation I
# [65/305] → Orders für: Small Energy Discharge Elutriation II
# [66/305] → Orders für: Small Energy Locus Coordinator I
# [67/305] → Orders für: Small Energy Locus Coordinator II
# [68/305] → Orders für: Small Energy Metastasis Adjuster I
# [69/305] → Orders für: Small Energy Metastasis Adjuster II
# [70/305] → Orders für: Medium Algid Energy Administrations Unit I
# [71/305] → Orders für: Medium Algid Energy Administrations Unit II
# [72/305] → Orders für: Medium Energy Ambit Extension I
# [73/305] → Orders für: Medium Energy Ambit Extension II
# [74/305] → Orders für: Medium Energy Burst Aerator I
# [75/305] → Orders für: Medium Energy Burst Aerator II
# [76/305] → Orders für: Medium Energy Collision Accelerator I
# [77/305] → Orders für: Medium Energy Collision Accelerator II
# [78/305] → Orders für: Medium Energy Discharge Elutriation I
# [79/305] → Orders für: Medium Energy Discharge Elutriation II
# [80/305] → Orders für: Medium Energy Locus Coordinator I
# [81/305] → Orders für: Medium Energy Locus Coordinator II
# [82/305] → Orders für: Medium Energy Metastasis Adjuster I
# [83/305] → Orders für: Medium Energy Metastasis Adjuster II
# [84/305] → Orders für: Large Energy Discharge Elutriation I
# [85/305] → Orders für: Large Energy Ambit Extension I
# [86/305] → Orders für: Large Energy Locus Coordinator I
# [87/305] → Orders für: Large Energy Metastasis Adjuster I
# [88/305] → Orders für: Large Algid Energy Administrations Unit I
# [89/305] → Orders für: Large Energy Burst Aerator I
# [90/305] → Orders für: Large Energy Collision Accelerator I
# [91/305] → Orders für: Large Energy Discharge Elutriation II
# [92/305] → Orders für: Large Energy Burst Aerator II
# [93/305] → Orders für: Large Energy Collision Accelerator II
# [94/305] → Orders für: Large Algid Energy Administrations Unit II
# [95/305] → Orders für: Large Energy Ambit Extension II
# [96/305] → Orders für: Large Energy Locus Coordinator II
# [97/305] → Orders für: Large Energy Metastasis Adjuster II
# [98/305] → Orders für: Small Algid Hybrid Administrations Unit I
# [99/305] → Orders für: Small Algid Hybrid Administrations Unit II
# [100/305] → Orders für: Small Hybrid Ambit Extension I
# [101/305] → Orders für: Small Hybrid Ambit Extension II
# [102/305] → Orders für: Small Hybrid Burst Aerator I
# [103/305] → Orders für: Small Hybrid Burst Aerator II
# [104/305] → Orders für: Small Hybrid Collision Accelerator I
# [105/305] → Orders für: Small Hybrid Collision Accelerator II
# [106/305] → Orders für: Small Hybrid Discharge Elutriation I
# [107/305] → Orders für: Small Hybrid Discharge Elutriation II
# [108/305] → Orders für: Small Hybrid Locus Coordinator I
# [109/305] → Orders für: Small Hybrid Locus Coordinator II
# [110/305] → Orders für: Small Hybrid Metastasis Adjuster I
# [111/305] → Orders für: Small Hybrid Metastasis Adjuster II
# [112/305] → Orders für: Medium Algid Hybrid Administrations Unit I
# [113/305] → Orders für: Medium Algid Hybrid Administrations Unit II
# [114/305] → Orders für: Medium Hybrid Ambit Extension I
# [115/305] → Orders für: Medium Hybrid Ambit Extension II
# [116/305] → Orders für: Medium Hybrid Burst Aerator I
# [117/305] → Orders für: Medium Hybrid Burst Aerator II
# [118/305] → Orders für: Medium Hybrid Collision Accelerator I
# [119/305] → Orders für: Medium Hybrid Collision Accelerator II
# [120/305] → Orders für: Medium Hybrid Discharge Elutriation I
# [121/305] → Orders für: Medium Hybrid Discharge Elutriation II
# [122/305] → Orders für: Medium Hybrid Locus Coordinator I
# [123/305] → Orders für: Medium Hybrid Locus Coordinator II
# [124/305] → Orders für: Medium Hybrid Metastasis Adjuster I
# [125/305] → Orders für: Medium Hybrid Metastasis Adjuster II
# [126/305] → Orders für: Large Hybrid Discharge Elutriation I
# [127/305] → Orders für: Large Hybrid Ambit Extension I
# [128/305] → Orders für: Large Hybrid Locus Coordinator I
# [129/305] → Orders für: Large Hybrid Metastasis Adjuster I
# [130/305] → Orders für: Large Algid Hybrid Administrations Unit I
# [131/305] → Orders für: Large Hybrid Burst Aerator I
# [132/305] → Orders für: Large Hybrid Collision Accelerator I
# [133/305] → Orders für: Large Hybrid Discharge Elutriation II
# [134/305] → Orders für: Large Hybrid Burst Aerator II
# [135/305] → Orders für: Large Hybrid Collision Accelerator II
# [136/305] → Orders für: Large Algid Hybrid Administrations Unit II
# [137/305] → Orders für: Large Hybrid Ambit Extension II
# [138/305] → Orders für: Large Hybrid Locus Coordinator II
# [139/305] → Orders für: Large Hybrid Metastasis Adjuster II
# [140/305] → Orders für: Small Projectile Ambit Extension I
# [141/305] → Orders für: Small Projectile Ambit Extension II
# [142/305] → Orders für: Small Projectile Burst Aerator I
# [143/305] → Orders für: Small Projectile Burst Aerator II
# [144/305] → Orders für: Small Projectile Collision Accelerator I
# [145/305] → Orders für: Small Projectile Collision Accelerator II
# [146/305] → Orders für: Small Projectile Locus Coordinator I
# [147/305] → Orders für: Small Projectile Locus Coordinator II
# [148/305] → Orders für: Small Projectile Metastasis Adjuster I
# [149/305] → Orders für: Small Projectile Metastasis Adjuster II
# [150/305] → Orders für: Medium Projectile Ambit Extension I
# [151/305] → Orders für: Medium Projectile Ambit Extension II
# [152/305] → Orders für: Medium Projectile Burst Aerator I
# [153/305] → Orders für: Medium Projectile Burst Aerator II
# [154/305] → Orders für: Medium Projectile Collision Accelerator I
# [155/305] → Orders für: Medium Projectile Collision Accelerator II
# [156/305] → Orders für: Medium Projectile Locus Coordinator I
# [157/305] → Orders für: Medium Projectile Locus Coordinator II
# [158/305] → Orders für: Medium Projectile Metastasis Adjuster I
# [159/305] → Orders für: Medium Projectile Metastasis Adjuster II
# [160/305] → Orders für: Large Projectile Ambit Extension I
# [161/305] → Orders für: Large Projectile Locus Coordinator I
# [162/305] → Orders für: Large Projectile Metastasis Adjuster I
# [163/305] → Orders für: Large Projectile Burst Aerator I
# [164/305] → Orders für: Large Projectile Collision Accelerator I
# [165/305] → Orders für: Large Projectile Collision Accelerator II
# [166/305] → Orders für: Large Projectile Ambit Extension II
# [167/305] → Orders für: Large Projectile Burst Aerator II
# [168/305] → Orders für: Large Projectile Locus Coordinator II
# [169/305] → Orders für: Large Projectile Metastasis Adjuster II
# [170/305] → Orders für: Small Algid Energy Administrations Unit I Blueprint
# [171/305] → Orders für: Small Energy Ambit Extension I Blueprint
# [172/305] → Orders für: Small Energy Burst Aerator I Blueprint
# [173/305] → Orders für: Small Energy Collision Accelerator I Blueprint
# [174/305] → Orders für: Small Energy Discharge Elutriation I Blueprint
# [175/305] → Orders für: Small Energy Locus Coordinator I Blueprint
# [176/305] → Orders für: Small Energy Metastasis Adjuster I Blueprint
# [177/305] → Orders für: Medium Algid Energy Administrations Unit I Blueprint
# [178/305] → Orders für: Medium Energy Ambit Extension I Blueprint
# [179/305] → Orders für: Medium Energy Burst Aerator I Blueprint
# [180/305] → Orders für: Medium Energy Collision Accelerator I Blueprint
# [181/305] → Orders für: Medium Energy Discharge Elutriation I Blueprint
# [182/305] → Orders für: Medium Energy Locus Coordinator I Blueprint
# [183/305] → Orders für: Medium Energy Metastasis Adjuster I Blueprint
# [184/305] → Orders für: Large Energy Discharge Elutriation I Blueprint
# [185/305] → Orders für: Large Energy Ambit Extension I Blueprint
# [186/305] → Orders für: Large Energy Locus Coordinator I Blueprint
# [187/305] → Orders für: Large Energy Metastasis Adjuster I Blueprint
# [188/305] → Orders für: Large Algid Energy Administrations Unit I Blueprint
# [189/305] → Orders für: Large Energy Burst Aerator I Blueprint
# [190/305] → Orders für: Large Energy Collision Accelerator I Blueprint
# [191/305] → Orders für: Small Algid Hybrid Administrations Unit I Blueprint
# [192/305] → Orders für: Small Hybrid Ambit Extension I Blueprint
# [193/305] → Orders für: Small Hybrid Burst Aerator I Blueprint
# [194/305] → Orders für: Small Hybrid Collision Accelerator I Blueprint
# [195/305] → Orders für: Small Hybrid Discharge Elutriation I Blueprint
# [196/305] → Orders für: Small Hybrid Locus Coordinator I Blueprint
# [197/305] → Orders für: Small Hybrid Metastasis Adjuster I Blueprint
# [198/305] → Orders für: Medium Algid Hybrid Administrations Unit I Blueprint
# [199/305] → Orders für: Medium Hybrid Ambit Extension I Blueprint
# [200/305] → Orders für: Medium Hybrid Burst Aerator I Blueprint
# [201/305] → Orders für: Medium Hybrid Collision Accelerator I Blueprint
# [202/305] → Orders für: Medium Hybrid Discharge Elutriation I Blueprint
# [203/305] → Orders für: Medium Hybrid Locus Coordinator I Blueprint
# [204/305] → Orders für: Medium Hybrid Metastasis Adjuster I Blueprint
# [205/305] → Orders für: Large Hybrid Discharge Elutriation I Blueprint
# [206/305] → Orders für: Large Hybrid Ambit Extension I Blueprint
# [207/305] → Orders für: Large Hybrid Locus Coordinator I Blueprint
# [208/305] → Orders für: Large Hybrid Metastasis Adjuster I Blueprint
# [209/305] → Orders für: Large Algid Hybrid Administrations Unit I Blueprint
# [210/305] → Orders für: Large Hybrid Burst Aerator I Blueprint
# [211/305] → Orders für: Large Hybrid Collision Accelerator I Blueprint
# [212/305] → Orders für: Small Projectile Ambit Extension I Blueprint
# [213/305] → Orders für: Small Projectile Burst Aerator I Blueprint
# [214/305] → Orders für: Small Projectile Collision Accelerator I Blueprint
# [215/305] → Orders für: Small Projectile Locus Coordinator I Blueprint
# [216/305] → Orders für: Small Projectile Metastasis Adjuster I Blueprint
# [217/305] → Orders für: Medium Projectile Ambit Extension I Blueprint
# [218/305] → Orders für: Medium Projectile Burst Aerator I Blueprint
# [219/305] → Orders für: Medium Projectile Collision Accelerator I Blueprint
# [220/305] → Orders für: Medium Projectile Locus Coordinator I Blueprint
# [221/305] → Orders für: Medium Projectile Metastasis Adjuster I Blueprint
# [222/305] → Orders für: Large Projectile Ambit Extension I Blueprint
# [223/305] → Orders für: Large Projectile Locus Coordinator I Blueprint
# [224/305] → Orders für: Large Projectile Metastasis Adjuster I Blueprint
# [225/305] → Orders für: Large Projectile Burst Aerator I Blueprint
# [226/305] → Orders für: Large Projectile Collision Accelerator I Blueprint
# [227/305] → Orders für: Tracking Disruptor I Blueprint
# [228/305] → Orders für: Guidance Disruptor I Blueprint
# [229/305] → Orders für: Deactivated Station Key Pass Blueprint
# [230/305] → Orders für: Capital Algid Energy Administrations Unit I Blueprint
# [231/305] → Orders für: Capital Energy Ambit Extension I Blueprint
# [232/305] → Orders für: Capital Energy Burst Aerator I Blueprint
# [233/305] → Orders für: Capital Energy Collision Accelerator I Blueprint
# [234/305] → Orders für: Capital Energy Discharge Elutriation I Blueprint
# [235/305] → Orders für: Capital Energy Locus Coordinator I Blueprint
# [236/305] → Orders für: Capital Energy Metastasis Adjuster I Blueprint
# [237/305] → Orders für: Capital Algid Hybrid Administrations Unit I Blueprint
# [238/305] → Orders für: Capital Hybrid Ambit Extension I Blueprint
# [239/305] → Orders für: Capital Hybrid Burst Aerator I Blueprint
# [240/305] → Orders für: Capital Hybrid Collision Accelerator I Blueprint
# [241/305] → Orders für: Capital Hybrid Discharge Elutriation I Blueprint
# [242/305] → Orders für: Capital Hybrid Locus Coordinator I Blueprint
# [243/305] → Orders für: Capital Hybrid Metastasis Adjuster I Blueprint
# [244/305] → Orders für: Capital Projectile Ambit Extension I Blueprint
# [245/305] → Orders für: Capital Projectile Burst Aerator I Blueprint
# [246/305] → Orders für: Capital Projectile Collision Accelerator I Blueprint
# [247/305] → Orders für: Capital Projectile Locus Coordinator I Blueprint
# [248/305] → Orders für: Capital Projectile Metastasis Adjuster I Blueprint
# [249/305] → Orders für: Capital Projectile Ambit Extension I
# [250/305] → Orders für: Capital Projectile Ambit Extension II
# [251/305] → Orders für: Capital Projectile Burst Aerator I
# [252/305] → Orders für: Capital Projectile Burst Aerator II
# [253/305] → Orders für: Capital Projectile Collision Accelerator I
# [254/305] → Orders für: Capital Projectile Collision Accelerator II
# [255/305] → Orders für: Capital Projectile Locus Coordinator I
# [256/305] → Orders für: Capital Projectile Locus Coordinator II
# [257/305] → Orders für: Capital Projectile Metastasis Adjuster I
# [258/305] → Orders für: Capital Projectile Metastasis Adjuster II
# [259/305] → Orders für: Capital Algid Hybrid Administrations Unit I
# [260/305] → Orders für: Capital Algid Hybrid Administrations Unit II
# [261/305] → Orders für: Capital Hybrid Ambit Extension I
# [262/305] → Orders für: Capital Hybrid Ambit Extension II
# [263/305] → Orders für: Capital Hybrid Burst Aerator I
# [264/305] → Orders für: Capital Hybrid Burst Aerator II
# [265/305] → Orders für: Capital Hybrid Collision Accelerator I
# [266/305] → Orders für: Capital Hybrid Collision Accelerator II
# [267/305] → Orders für: Capital Hybrid Discharge Elutriation I
# [268/305] → Orders für: Capital Hybrid Discharge Elutriation II
# [269/305] → Orders für: Capital Hybrid Locus Coordinator I
# [270/305] → Orders für: Capital Hybrid Locus Coordinator II
# [271/305] → Orders für: Capital Hybrid Metastasis Adjuster I
# [272/305] → Orders für: Capital Hybrid Metastasis Adjuster II
# [273/305] → Orders für: Capital Algid Energy Administrations Unit I
# [274/305] → Orders für: Capital Algid Energy Administrations Unit II
# [275/305] → Orders für: Capital Energy Ambit Extension I
# [276/305] → Orders für: Capital Energy Ambit Extension II
# [277/305] → Orders für: Capital Energy Burst Aerator I
# [278/305] → Orders für: Capital Energy Burst Aerator II
# [279/305] → Orders für: Capital Energy Collision Accelerator I
# [280/305] → Orders für: Capital Energy Collision Accelerator II
# [281/305] → Orders für: Capital Energy Discharge Elutriation I
# [282/305] → Orders für: Capital Energy Discharge Elutriation II
# [283/305] → Orders für: Capital Energy Locus Coordinator I
# [284/305] → Orders für: Capital Energy Locus Coordinator II
# [285/305] → Orders für: Capital Energy Metastasis Adjuster I
# [286/305] → Orders für: Capital Energy Metastasis Adjuster II
# [287/305] → Orders für: Standup Weapon Disruptor I Blueprint
# [288/305] → Orders für: Standup Weapon Disruptor I
# [289/305] → Orders für: Standup Weapon Disruptor II
# [290/305] → Orders für: Skill Extractor
# [291/305] → Orders für: Large Skill Injector
# [292/305] → Orders für: Small Skill Injector
# [293/305] → Orders für: Daily Alpha Injector
# [294/305] → Orders für: Medium Asteroid Ore Compressor I Blueprint
# [295/305] → Orders für: Large Asteroid Ore Compressor I Blueprint
# [296/305] → Orders für: Capital Asteroid Ore Compressor I Blueprint
# [297/305] → Orders für: Large Ice Compressor I Blueprint
# [298/305] → Orders für: Capital Ice Compressor I Blueprint
# [299/305] → Orders für: Medium Gas Compressor I Blueprint
# [300/305] → Orders für: Large Gas Compressor I Blueprint
# [301/305] → Orders für: Capital Gas Compressor I Blueprint
# [302/305] → Orders für: Large Mercoxit Compressor I Blueprint
# [303/305] → Orders für: Capital Mercoxit Compressor I Blueprint
# [304/305] → Orders für: Large Moon Ore Compressor I Blueprint
# [305/305] → Orders für: Capital Moon Ore Compressor I Blueprint
# ✅ Sell-Orders geladen: 25,826
# ✅ Tabelle erstellt: 246 Items
#
# 📈 Top 500 Sell→Sell-Spreads (Station-aggregiert, je Station min Preis):
#                                                   Item  Einkaufspreis [ISK]                                       Einkaufs-Ort  Verkaufspreis [ISK] (niedrigste Sell an Zielstation)                                       Verkaufs-Ort   Spread [ISK]    Spread [%]  Volumen (Einkaufs-Station)  Volumen (Verkaufs-Station)
# 0                      DDO Scoped Tracking Disruptor I                12.12  Cleyd V - Carthum Conglomerate Factory (Cleyd,...                                       1,710,000.00     PR-8CA III - Blood Raiders Logistic Support (P...   1,709,987.88 14,108,810.89                           1                          94
# 1           Balmer Series Compact Tracking Disruptor I               144.10  Cleyd V - Carthum Conglomerate Factory (Cleyd,...                                       2,499,000.00     1DH-SX III - Moon 1 - Blood Raiders Logistic S...   2,498,855.90  1,734,112.35                           1                          12
# 2                      C-IR Compact Guidance Disruptor               100.10  Clellinon VI - Moon 11 - Center for Advanced S...                                         990,900.00     319-3D IX - Moon 22 - Blood Raiders Logistic S...     990,799.90    989,810.09                           3                          38
# 3                 Highstroke Scoped Guidance Disruptor             3,500.00  Rens VI - Moon 8 - Brutor Tribe Treasury (Rens...                                      22,230,000.00     Jita VI - Paragon Fulfillment Center (Jita, 10...  22,226,500.00    635,042.86                          75                           1
# 4                                 Tracking Disruptor I            29,830.00  Thera XII - The Sanctuary Surveillance Observa...                                      25,000,000.00     Berta VI - Moon 19 - Ammatar Consulate Bureau ...  24,970,170.00     83,708.25                           9                           1
# 5                    A-211 Enduring Guidance Disruptor             3,005.00  Korama II - Moon 5 - Republic Security Service...                                       1,000,000.00     Boystin V - Moon 6 - Federal Intelligence Offi...     996,995.00     33,177.87                           4                          20
